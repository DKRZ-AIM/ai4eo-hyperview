# %% [markdown]
# Load and visualize hyperparamers from random forest

# %%
# !pip install joblib
# !pip install optuna
# !pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 28.8 MB 2.7 MB/s eta 0:00:01
# ...

# %%
import os
import joblib
import optuna
from optuna.visualization import plot_optimization_history
from optuna.visualization import plot_parallel_coordinate

# %%
study_path = "/mnt/lustre02/work/ka1176/frauke/ai4eo-hyperview/hyperview/random_forest/submissions"
study_name = "study_rf_n_est=862.pkl"
study = os.path.join(study_path, study_name)
study = joblib.load(study)
print("Best trial until now:")
print(" Value: ", study.best_trial.value)
print(" Params: ")
for key, value in study.best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# Best trial until now:
#  Value:  1.1292355829951624
#  Params:
#     n_estimators: 862

# %%
optuna.visualization.matplotlib.plot_param_importances(study)
# Out:
# <ipython-input-20-a5c7740d20da>:1: ExperimentalWarning: plot_param_importances is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_param_importances(study)
# <AxesSubplot:title={'center':'Hyperparameter Importances'}, xlabel='Importance for Objective Value', ylabel='Hyperparameter'>

# %%
optuna.visualization.matplotlib.plot_optimization_history(study)
# Out:
# <ipython-input-21-471f79a759ba>:1: ExperimentalWarning: plot_optimization_history is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_optimization_history(study)
# <AxesSubplot:title={'center':'Optimization History Plot'}, xlabel='#Trials', ylabel='Objective Value'>

# %%
optuna.visualization.matplotlib.plot_parallel_coordinate(study)
# Out:
# <ipython-input-22-7be1e8294286>:1: ExperimentalWarning: plot_parallel_coordinate is experimental (supported from v2.2.0). The interface can change in the future.
#   optuna.visualization.matplotlib.plot_parallel_coordinate(study)
# <AxesSubplot:title={'center':'Parallel Coordinate Plot'}>
